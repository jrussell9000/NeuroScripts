# %%
import sys
import pandas as pd
from pathlib import Path
from IPython.display import clear_output
import dask
from dask import dataframe as dd
import numpy as np
import tensorflow as tf

# %%
pconncsv_dir = Path('/fast_scratch/jdr/ABCD/ABCD_3165_Pipe/pconns_working/pconn_csv')
subjIDs = []
allArrays = []

for pconncsv in pconncsv_dir.glob('*.csv'):
    clear_output(wait=True)
    subjIDs.append(pconncsv.name.split('_')[0])
    
    csv_in_sq = pd.read_csv(pconncsv, sep="\t", header=None).values
    csv_in_flat = csv_in_sq[np.tril_indices(453, k = -1)]
    
    if len(allArrays) == 0:
        allArrays = csv_in_flat
    else:
        allArrays = np.vstack((allArrays, csv_in_flat))
    print(pconncsv)
    
allArraysPath = Path('/fast_scratch/jdr/ABCD/ABCD_3165_Pipe/Data/allArrays.npy')
np.save(allArraysPath, allArrays)

subjIDs_arrayPath = Path('/fast_scratch/jdr/ABCD/ABCD_3165_Pipe/Data/subjIDs.npy')
np.save(subjIDs_arrayPath, np.asarray(subjIDs))
# Out:
# /fast_scratch/jdr/ABCD/ABCD_3165_Pipe/pconns_working/pconn_csv/sub-NDARINVZZZNB0XC_ses-baselineYear1Arm1_task-rest_bold_desc-filtered_timeseries.ptseries.nii_8_minutes_of_data_at_FD_0.2.pconn.nii.csv

# %%
c_data = pd.read_table('/fast_scratch/jdr/ABCD/ABCD_3165_Pipe/Data/abcd_ptsd01.txt', header=0, skiprows=[1])
c_data = c_data[c_data["eventname"] == "baseline_year_1_arm_1"]
c_data = c_data.drop(['collection_id', 'abcd_ptsd01_id', 'dataset_id', 
                      'src_subject_id', 'interview_date', 'eventname', 'collection_title'], axis=1)
c_data['subjectkey'] = 'sub-' + c_data['subjectkey'].str.replace('_', '')
c_data = c_data.drop(['ExposureTotal', 'IPVTotal'], axis=1, errors='ignore')
c_data['ExposureTotal'] = c_data.iloc[:, 3:19].sum(axis=1)
c_data['IPVTotal'] = c_data.iloc[:, 7:18].sum(axis=1)
c_data['ExposureAny'] = np.where(c_data['ExposureTotal'] == 0, 0, 1)
c_data['IPVAny'] = np.where(c_data['IPVTotal'] == 0, 0, 1)
c_data['Sex01'] = np.where(c_data['sex'] == 'M', 1, 0) # Must use numeric data as input (not M, F)

# %%
subjIDs_df = pd.DataFrame(subjIDs,columns=['subjectkey'])
 = subjIDs_df.merge(c_data, how='left', on='subjectkey')
df_comb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7220 entries, 0 to 7219
# Data columns (total 25 columns):
# subjectkey              7220 non-null object
# interview_age           7216 non-null float64
# sex                     7216 non-null object
# ksads_ptsd_raw_754_p    7004 non-null float64
# ksads_ptsd_raw_755_p    7004 non-null float64
# ksads_ptsd_raw_756_p    7004 non-null float64
# ksads_ptsd_raw_757_p    7004 non-null float64
# ksads_ptsd_raw_758_p    7004 non-null float64
# ksads_ptsd_raw_759_p    7004 non-null float64
# ksads_ptsd_raw_760_p    7004 non-null float64
# ksads_ptsd_raw_761_p    7004 non-null float64
# ksads_ptsd_raw_762_p    7004 non-null float64
# ksads_ptsd_raw_763_p    7004 non-null float64
# ksads_ptsd_raw_764_p    7004 non-null float64
# ksads_ptsd_raw_765_p    7004 non-null float64
# ksads_ptsd_raw_766_p    7004 non-null float64
# ksads_ptsd_raw_767_p    7004 non-null float64
# ksads_ptsd_raw_768_p    7004 non-null float64
# ksads_ptsd_raw_769_p    7004 non-null float64
# ksads_ptsd_raw_770_p    7004 non-null float64
# ExposureAny             7216 non-null float64
# IPVAny                  7216 non-null float64
# ExposureTotal           7216 non-null float64
# IPVTotal                7216 non-null float64
# Sex01                   7216 non-null float64
# dtypes: float64(23), object(2)
# memory usage: 1.4+ MB

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(allArrays, df_comb['Sex01'].values)

# %%
subjIDs
# Out:
# ['sub-NDARINV003RTV85',
#  'sub-NDARINV007W6H7B',
#  'sub-NDARINV00BD7VDC',
#  'sub-NDARINV00HEV6HB',
#  'sub-NDARINV00J52GPG',
#  'sub-NDARINV00LH735Y',
#  'sub-NDARINV00NPMHND',
#  'sub-NDARINV00R4TXET',
#  'sub-NDARINV00U4FTRU',
#  'sub-NDARINV01AJ15N9',
#  'sub-NDARINV01ELX9L6',
#  'sub-NDARINV01EN91PG',
#  'sub-NDARINV01NAYMZH',
#  'sub-NDARINV01RGTWD2',
#  'sub-NDARINV01Z8HAPV',
#  'sub-NDARINV021403LF',
#  'sub-NDARINV022ZVCT8',
#  'sub-NDARINV028D3ELL',
#  'sub-NDARINV02EBX0JJ',
#  'sub-NDARINV02H7G2T6',
#  'sub-NDARINV02JXJUZG',
#  'sub-NDARINV02RCED7D',
#  'sub-NDARINV02UVMTY7',
#  'sub-NDARINV02WP3TP6',
#  'sub-NDARINV030W95VP',
#  'sub-NDARINV030X9ZNH',
#  'sub-NDARINV03BDCNWM',
#  'sub-NDARINV03CV8RDT',
#  'sub-NDARINV03NW0RKL',
#  'sub-NDARINV03XVEBPM',
#  'sub-NDARINV040B4TRC',
#  'sub-NDARINV042UJKFB',
#  'sub-NDARINV04CLBZAD',
#  'sub-NDARINV04EUBGTM',
#  'sub-NDARINV04GAB2AA',
#  'sub-NDARINV04JY6730',
#  'sub-NDARINV052HU3CU',
#  'sub-NDARINV059VLAHF',
#  'sub-NDARINV05ATJ1V1',
#  'sub-NDARINV05CA3VX5',
#  'sub-NDARINV05LGG3GZ',
#  'sub-NDARINV05X0LM1N',
#  'sub-NDARINV05YY477E',
#  'sub-NDARINV06A9DLE9',
#  'sub-NDARINV06BKAHN5',
#  'sub-NDARINV06DE9Y0L',
#  'sub-NDARINV06DP74KL',
#  'sub-NDARINV06TBFD6R',
#  'sub-NDARINV06U4DYFY',
#  'sub-NDARINV06WHVUPX',
#  'sub-NDARINV07924XF1',
#  'sub-NDARINV07BR8GMY',
#  'sub-NDARINV07K2M5P4',
#  'sub-NDARINV07RAHHYH',
#  'sub-NDARINV07THBLHG',
#  'sub-NDARINV07XG8391',
#  'sub-NDARINV07XXFHDK',
#  'sub-NDARINV085CYDEZ',
#  'sub-NDARINV086U18RD',
#  'sub-NDARINV0889M0JE',
#  'sub-NDARINV08AT7TLH',
#  'sub-NDARINV08DNLREC',
#  'sub-NDARINV08FUB58A',
#  'sub-NDARINV08GBDG8X',
#  'sub-NDARINV08J0E48V',
#  'sub-NDARINV08K0R9C4',
#  'sub-NDARINV08K8VF33',
#  'sub-NDARINV08P3GNDV',
#  'sub-NDARINV08R2PTT1',
#  'sub-NDARINV08YFFYY2',
#  'sub-NDARINV095EVLDD',
#  'sub-NDARINV097LUBWX',
#  'sub-NDARINV09AEBLZH',
#  'sub-NDARINV09AKV10T',
#  'sub-NDARINV09AUXBBT',
#  'sub-NDARINV09C3ZNFZ',
#  'sub-NDARINV0A4P0LWM',
#  'sub-NDARINV0A6WVRZY',
#  'sub-NDARINV0A86UD86',
#  'sub-NDARINV0A87RKWD',
#  'sub-NDARINV0A9K5L4R',
#  'sub-NDARINV0AEBMADL',
#  'sub-NDARINV0APJMRD1',
#  'sub-NDARINV0AU5R8NA',
#  'sub-NDARINV0AYJMFMW',
#  'sub-NDARINV0BL9EL2Y',
#  'sub-NDARINV0BVP2PTD',
#  'sub-NDARINV0BXXNBH4',
#  'sub-NDARINV0C471G23',
#  'sub-NDARINV0C765WK4',
#  'sub-NDARINV0CBFTKR7',
#  'sub-NDARINV0CBPKF6W',
#  'sub-NDARINV0CCMBWPE',
#  'sub-NDARINV0CCVJ39W',
#  'sub-NDARINV0CF1U8X8',
#  'sub-NDARINV0CFR33F0',
#  'sub-NDARINV0CKA3YZX',
#  'sub-NDARINV0CP9XGTP',
#  'sub-NDARINV0CV2Y4YR',
#  'sub-NDARINV0CZBUV4C',
#  'sub-NDARINV0D4C1R8X',
#  'sub-NDARINV0D83M5VE',
#  'sub-NDARINV0DBRJXKG',
#  'sub-NDARINV0DC9BJZK',
#  'sub-NDARINV0DG8XR2P',
#  'sub-NDARINV0DJJP33V',
#  'sub-NDARINV0DKWEM1A',
#  'sub-NDARINV0DMRP60R',
#  'sub-NDARINV0DUXE0ZA',
#  'sub-NDARINV0DVK13LU',
#  'sub-NDARINV0DYF4WPG',
#  'sub-NDARINV0E1RBR9J',
#  'sub-NDARINV0E4CT74P',
#  'sub-NDARINV0E9UFT0K',
#  'sub-NDARINV0EV57VEX',
#  'sub-NDARINV0EVRF8BN',
#  'sub-NDARINV0EXY6KFW',
#  'sub-NDARINV0F3UJ9CT',
#  'sub-NDARINV0F82C6R8',
#  'sub-NDARINV0F959U85',
#  'sub-NDARINV0FCEX8C6',
#  'sub-NDARINV0FV544H9',
#  'sub-NDARINV0FZ2J7TT',
#  'sub-NDARINV0G2N59GL',
#  'sub-NDARINV0G42TBW1',
#  'sub-NDARINV0GGJJ4H9',
#  'sub-NDARINV0GPKYMDC',
#  'sub-NDARINV0GUTM6AM',
#  'sub-NDARINV0GVW93X6',
#  'sub-NDARINV0GWJ7GFF',
#  'sub-NDARINV0GYC1NWR',
#  'sub-NDARINV0GZ334XA',
#  'sub-NDARINV0GZM9UZJ',
#  'sub-NDARINV0H05G0TR',
#  'sub-NDARINV0HH094Z9',
#  'sub-NDARINV0HL5D3DF',
#  'sub-NDARINV0HVEVD01',
#  'sub-NDARINV0HXXANFJ',
#  'sub-NDARINV0J1M2ETU',
#  'sub-NDARINV0JAG7BGC',
#  'sub-NDARINV0JGVD4F3',
#  'sub-NDARINV0JR6Y529',
#  'sub-NDARINV0JRNB4U4',
#  'sub-NDARINV0JRU5DWA',
#  'sub-NDARINV0JVUB582',
#  'sub-NDARINV0JWEE23L',
#  'sub-NDARINV0JXBZBV9',
#  'sub-NDARINV0K37T6VD',
#  'sub-NDARINV0L3VJZEL',
#  'sub-NDARINV0L7K5UMC',
#  'sub-NDARINV0L7XB3AW',
#  'sub-NDARINV0L974J49',
#  'sub-NDARINV0LA6MBBY',
#  'sub-NDARINV0LEM88KP',
#  'sub-NDARINV0LKZCJ15',
#  'sub-NDARINV0LN1KD13',
#  'sub-NDARINV0M0EWKRV',
#  'sub-NDARINV0M9U5RX8',
#  'sub-NDARINV0MF9V4P1',
#  'sub-NDARINV0ML93ZXT',
#  'sub-NDARINV0MPBK7TU',
#  'sub-NDARINV0MRY4Z3E',
#  'sub-NDARINV0MXJ7AZN',
#  'sub-NDARINV0N10CEEL',
#  'sub-NDARINV0N289PCW',
#  'sub-NDARINV0N4E3EM7',
#  'sub-NDARINV0N5WVJ17',
#  'sub-NDARINV0NGG5VLJ',
#  'sub-NDARINV0NLL2KYE',
#  'sub-NDARINV0NR55WME',
#  'sub-NDARINV0P0GTDY0',
#  'sub-NDARINV0P2ZCYPM',
#  'sub-NDARINV0P34UPZ9',
#  'sub-NDARINV0P3ERKVG',
#  'sub-NDARINV0P4XZMZA',
#  'sub-NDARINV0PDYPPJ7',
#  'sub-NDARINV0PJ81CA5',
#  'sub-NDARINV0PKCP1P3',
#  'sub-NDARINV0PLKFP06',
#  'sub-NDARINV0PRHUTZA',
#  'sub-NDARINV0R5220TJ',
#  'sub-NDARINV0RHDH1EL',
#  'sub-NDARINV0RHLKA9M',
#  'sub-NDARINV0RL1BGTN',
#  'sub-NDARINV0T41MTFH',
#  'sub-NDARINV0T7889MV',
#  'sub-NDARINV0TJZ2RA3',
#  'sub-NDARINV0TRD5ZK4',
#  'sub-NDARINV0U23M45G',
#  'sub-NDARINV0U317B9P',
#  'sub-NDARINV0UD3BJFR',
#  'sub-NDARINV0UEA3Z9E',
#  'sub-NDARINV0UL9YFZJ',
#  'sub-NDARINV0ULZKXXG',
#  'sub-NDARINV0UMM15GY',
#  'sub-NDARINV0UPRUMA1',
#  'sub-NDARINV0UPVEC1J',
#  'sub-NDARINV0UV5WZUN',
#  'sub-NDARINV0V1TNU11',
#  'sub-NDARINV0V1TYBKE',
#  'sub-NDARINV0V80916L',
#  'sub-NDARINV0V9W14U5',
#  'sub-NDARINV0VJZ6NZY',
#  'sub-NDARINV0VL8XV09',
#  'sub-NDARINV0VXEC29A',
#  'sub-NDARINV0VY70352',
#  'sub-NDARINV0W00RU2X',
#  'sub-NDARINV0W4PR2WT',
#  'sub-NDARINV0W4WA8RV',
#  'sub-NDARINV0WAF57A4',
#  'sub-NDARINV0WELU60J',
#  'sub-NDARINV0WTM31V7',
#  'sub-NDARINV0X38WL5R',
#  'sub-NDARINV0X4A2LKW',
#  'sub-NDARINV0X59EG8X',
#  'sub-NDARINV0XDBADBW',
#  'sub-NDARINV0XFVW4LF',
#  'sub-NDARINV0XKVPBB0',
#  'sub-NDARINV0XM20K74',
#  'sub-NDARINV0XTAYD1B',
#  'sub-NDARINV0XU7Z6RH',
#  'sub-NDARINV0XVGNCYR',
#  'sub-NDARINV0Y2153YG',
#  'sub-NDARINV0Y8YJ2UR',
#  'sub-NDARINV0Y9GR364',
#  'sub-NDARINV0YLLNXRL',
#  'sub-NDARINV0YMH4BW6',
#  'sub-NDARINV0YVKYMJX',
#  'sub-NDARINV0YWBYAGP',
#  'sub-NDARINV0ZAYELPK',
#  'sub-NDARINV0ZHHWCMZ',
#  'sub-NDARINV0ZPPK2ML',
#  'sub-NDARINV0ZTJ2432',
#  'sub-NDARINV101HGWPC',
#  'sub-NDARINV102P9DCN',
#  'sub-NDARINV109GUWFN',
#  'sub-NDARINV10DN9UHY',
#  'sub-NDARINV10F7NTCV',
#  'sub-NDARINV10HWA6YU',
#  'sub-NDARINV10J5M8LB',
#  'sub-NDARINV10K9CVX2',
#  'sub-NDARINV10KHJFTG',
#  'sub-NDARINV10RNF3BK',
#  'sub-NDARINV10T1UELH',
#  'sub-NDARINV10TEADFM',
#  'sub-NDARINV112R12P1',
#  'sub-NDARINV1147ELD2',
#  'sub-NDARINV114VT9DX',
#  'sub-NDARINV11THDW9B',
#  'sub-NDARINV12NED96V',
#  'sub-NDARINV12WR8W3U',
#  'sub-NDARINV1306ZGW1',
#  'sub-NDARINV1378XGLA',
#  'sub-NDARINV137Y0WR8',
#  'sub-NDARINV138RG20T',
#  'sub-NDARINV139PZ31D',
#  'sub-NDARINV13AC41PB',
#  'sub-NDARINV13FP25D3',
#  'sub-NDARINV13GH02YK',
#  'sub-NDARINV13LFMTL6',
#  'sub-NDARINV13PRF0TM',
#  'sub-NDARINV14992W6G',
#  'sub-NDARINV14BPGL15',
#  'sub-NDARINV14C1N3KZ',
#  'sub-NDARINV14PHMUNU',
#  'sub-NDARINV14PNN5H9',
#  'sub-NDARINV14R3MHDX',
#  'sub-NDARINV14UJARAJ',
#  'sub-NDARINV14ZFCHTA',
#  'sub-NDARINV1510CJF1',
#  'sub-NDARINV1535421B',
#  'sub-NDARINV1555HTEC',
#  'sub-NDARINV155U91DU',
#  'sub-NDARINV158CYMLK',
#  'sub-NDARINV15M33G49',
#  'sub-NDARINV15YZBNE0',
#  'sub-NDARINV165NRNVG',
#  'sub-NDARINV165XZRTA',
#  'sub-NDARINV16C687G5',
#  'sub-NDARINV16FHYZYY',
#  'sub-NDARINV16RVU5PF',
#  'sub-NDARINV170X8DA0',
#  'sub-NDARINV173ZYYKX',
#  'sub-NDARINV174DUV2F',
#  'sub-NDARINV174LD3GC',
#  'sub-NDARINV17K4X0WD',
#  'sub-NDARINV17N7VX8E',
#  'sub-NDARINV17UL1T8L',
#  'sub-NDARINV18BE29T0',
#  'sub-NDARINV18E23PK7',
#  'sub-NDARINV18H0Y70H',
#  'sub-NDARINV18HXV64A',
#  'sub-NDARINV18KWP8N1',
#  'sub-NDARINV18KYVZ3C',
#  'sub-NDARINV18RUWAJN',
#  'sub-NDARINV18X6GN95',
#  'sub-NDARINV18XYL4BV',
#  'sub-NDARINV18YX7994',
#  'sub-NDARINV1925AD9X',
#  'sub-NDARINV1962GTLL',
#  'sub-NDARINV19BR9YHW',
#  'sub-NDARINV19FYU534',
#  'sub-NDARINV19GEFHUC',
#  'sub-NDARINV19GP5HLJ',
#  'sub-NDARINV19JV1ZX5',
#  'sub-NDARINV19LRBB0U',
#  'sub-NDARINV19P33RVR',
#  'sub-NDARINV19UPJ1X0',
#  'sub-NDARINV1A1Y0V5X',
#  'sub-NDARINV1A8C7PRA',
#  'sub-NDARINV1AA2VG9C',
#  'sub-NDARINV1ACWERC3',
#  'sub-NDARINV1AFNKM8M',
#  'sub-NDARINV1AJNN0V2',
#  'sub-NDARINV1AKMLL9A',
#  'sub-NDARINV1APPZYY8',
#  'sub-NDARINV1AURDG78',
#  'sub-NDARINV1AYVNP3L',
#  'sub-NDARINV1B4T30A9',
#  'sub-NDARINV1B7G7LND',
#  'sub-NDARINV1BE1UD48',
#  'sub-NDARINV1BGRYN2J',
#  'sub-NDARINV1BHHLZ52',
#  'sub-NDARINV1BPLGEZ5',
#  'sub-NDARINV1BR989ED',
#  'sub-NDARINV1BTYWJDX',
#  'sub-NDARINV1BUXN6LH',
#  'sub-NDARINV1CC6HB4A',
#  'sub-NDARINV1CCL4UAD',
#  'sub-NDARINV1CGKKTM5',
#  'sub-NDARINV1CKXVV32',
#  'sub-NDARINV1CMWHGWK',
#  'sub-NDARINV1CRC8UTU',
#  'sub-NDARINV1CTLWW8V',
#  'sub-NDARINV1CYTVBWT',
#  'sub-NDARINV1D42VFML',
#  'sub-NDARINV1D6G642B',
#  'sub-NDARINV1D95ZF1L',
#  'sub-NDARINV1DZ2VF5K',
#  'sub-NDARINV1DZWFKCG',
#  'sub-NDARINV1E2PBKXL',
#  'sub-NDARINV1E4F8UMB',
#  'sub-NDARINV1EECRFPM',
#  'sub-NDARINV1ELP5894',
#  'sub-NDARINV1ENGFTE3',
#  'sub-NDARINV1ERVN8M1',
#  'sub-NDARINV1EZ26N40',
#  'sub-NDARINV1F6MVGKL',
#  'sub-NDARINV1F953XCP',
#  'sub-NDARINV1FDC7YAJ',
#  'sub-NDARINV1FGBFDT9',
#  'sub-NDARINV1FGX3DL8',
#  'sub-NDARINV1FRN7VDM',
#  'sub-NDARINV1FT79EHP',
#  'sub-NDARINV1FW43D9V',
#  'sub-NDARINV1G6W1PLY',
#  'sub-NDARINV1GDLVYHH',
#  'sub-NDARINV1GDR72XA',
#  'sub-NDARINV1GJJVVLZ',
#  'sub-NDARINV1GL1F6FK',
#  'sub-NDARINV1GTKW6ZG',
#  'sub-NDARINV1GVYL05C',
#  'sub-NDARINV1H63RRB3',
#  'sub-NDARINV1HKCTUW1',
#  'sub-NDARINV1J2LV4NY',
#  'sub-NDARINV1JAFHY62',
#  'sub-NDARINV1JC1WW5Y',
#  'sub-NDARINV1JERB432',
#  'sub-NDARINV1JGK90HZ',
#  'sub-NDARINV1JWGJFFK',
#  'sub-NDARINV1JXDFV9Z',
#  'sub-NDARINV1JZ17724',
#  'sub-NDARINV1K1285TU',
#  'sub-NDARINV1K2D2FB3',
#  'sub-NDARINV1K3LDK3L',
#  'sub-NDARINV1KHXW139',
#  'sub-NDARINV1KP8VFVR',
#  'sub-NDARINV1KWBW4RD',
#  'sub-NDARINV1KX54GYB',
#  'sub-NDARINV1KXK7MDF',
#  'sub-NDARINV1KZKJNFD',
#  'sub-NDARINV1L1ZCWL5',
#  'sub-NDARINV1L5VJRZG',
#  'sub-NDARINV1LC5DBRK',
#  'sub-NDARINV1LMYDNRY',
#  'sub-NDARINV1LRNM6EU',
#  'sub-NDARINV1LW4GJ4L',
#  'sub-NDARINV1MF1L9LR',
#  'sub-NDARINV1MFM0HL1',
#  'sub-NDARINV1MGXHNDZ',
#  'sub-NDARINV1MKWVMP1',
#  'sub-NDARINV1ML5RVV4',
#  'sub-NDARINV1MYF7VFL',
#  'sub-NDARINV1MZ6AG9P',
#  'sub-NDARINV1N0V1BUP',
#  'sub-NDARINV1NBATKW5',
#  'sub-NDARINV1NJK6BVY',
#  'sub-NDARINV1NV489TJ',
#  'sub-NDARINV1NY2HJJM',
#  'sub-NDARINV1NZMD6UK',
#  'sub-NDARINV1P29RX5F',
#  'sub-NDARINV1P4JN8JH',
#  'sub-NDARINV1P7L5P3B',
#  'sub-NDARINV1P86DC69',
#  'sub-NDARINV1PB7CJTH',
#  'sub-NDARINV1PE0ZVR4',
#  'sub-NDARINV1PHTC329',
#  'sub-NDARINV1PMXF3DY',
#  'sub-NDARINV1PN1MPWF',
#  'sub-NDARINV1PX9GGJP',
#  'sub-NDARINV1PYEEE1R',
#  'sub-NDARINV1R1AVH6W',
#  'sub-NDARINV1R4G3839',
#  'sub-NDARINV1R4KE1UN',
#  'sub-NDARINV1R5PJCK4',
#  'sub-NDARINV1R97KJ7J',
#  'sub-NDARINV1RC54TNX',
#  'sub-NDARINV1RE32C3R',
#  'sub-NDARINV1T4GDEXG',
#  'sub-NDARINV1TM2HNZW',
#  'sub-NDARINV1TRH3MMU',
#  'sub-NDARINV1TWMU0JK',
#  'sub-NDARINV1U3RR4GV',
#  'sub-NDARINV1U4C4M56',
#  'sub-NDARINV1U54HX62',
#  'sub-NDARINV1U58UMN8',
#  'sub-NDARINV1UNYCP25',
#  'sub-NDARINV1UWWV5JP',
#  'sub-NDARINV1V08GVK8',
#  'sub-NDARINV1V752R9N',
#  'sub-NDARINV1V7XPJKR',
#  'sub-NDARINV1VCF7KC6',
#  'sub-NDARINV1VCGLA8W',
#  'sub-NDARINV1VKHC02B',
#  'sub-NDARINV1VMB1ZYW',
#  'sub-NDARINV1VVMK6CP',
#  'sub-NDARINV1VZJUUZ9',
#  'sub-NDARINV1W2D4CFP',
#  'sub-NDARINV1W5TLB74',
#  'sub-NDARINV1WED9TPM',
#  'sub-NDARINV1WG8AL3V',
#  'sub-NDARINV1WJX687U',
#  'sub-NDARINV1WUAF4RW',
#  'sub-NDARINV1WVHVGH7',
#  'sub-NDARINV1X4F1YB5',
#  'sub-NDARINV1XLM62BZ',
#  'sub-NDARINV1Y3BE09E',
#  'sub-NDARINV1Y40DZT8',
#  'sub-NDARINV1Y89NGUJ',
#  'sub-NDARINV1YE699WK',
#  'sub-NDARINV1YFEDW44',
#  'sub-NDARINV1YWMB9TV',
#  'sub-NDARINV1Z1PW22B',
#  'sub-NDARINV1Z2F3AA0',
#  'sub-NDARINV1ZD6AF6H',
#  'sub-NDARINV1ZK1A3NG',
#  'sub-NDARINV1ZK55NV1',
#  'sub-NDARINV1ZKDLXEY',
#  'sub-NDARINV1ZMY808V',
#  'sub-NDARINV1ZY3ZR47',
#  'sub-NDARINV1ZZAPY9K',
#  'sub-NDARINV20453XZE',
#  'sub-NDARINV2051NM7L',
#  'sub-NDARINV20CNYBBC',
#  'sub-NDARINV20GGC8X5',
#  'sub-NDARINV20KZBB9N',
#  'sub-NDARINV20MDTUZ8',
#  'sub-NDARINV20MXZPW5',
#  'sub-NDARINV20NDWAH8',
#  'sub-NDARINV21BW63DB',
#  'sub-NDARINV21C5BFGC',
#  'sub-NDARINV21EBHGF9',
#  'sub-NDARINV21KEUZ1N',
#  'sub-NDARINV21YRAN0R',
#  'sub-NDARINV21YVF1WJ',
#  'sub-NDARINV21ZAXTA3',
#  'sub-NDARINV229XUWRH',
#  'sub-NDARINV22BFDVEJ',
#  'sub-NDARINV22C4YKXN',
#  'sub-NDARINV22E7G6BN',
#  'sub-NDARINV22F4J621',
#  'sub-NDARINV22GE0DMV',
#  'sub-NDARINV22GRHDPN',
#  'sub-NDARINV2358EMKW',
#  'sub-NDARINV23E4LDJX',
#  'sub-NDARINV23PJ8ECJ',
#  'sub-NDARINV23XF318V',
#  'sub-NDARINV23XHKMH5',
#  'sub-NDARINV23XZD51D',
#  'sub-NDARINV243VF1J7',
#  'sub-NDARINV249JM0NY',
#  'sub-NDARINV24BT0Y26',
#  'sub-NDARINV24D005FC',
#  'sub-NDARINV24KDRDL2',
#  'sub-NDARINV24LWV4C5',
#  'sub-NDARINV24MJ2521',
#  'sub-NDARINV24V8FLZ3',
#  'sub-NDARINV24W171KY',
#  'sub-NDARINV24YLW97V',
#  'sub-NDARINV2547FH92',
#  'sub-NDARINV2563J20P',
#  'sub-NDARINV25D23GPR',
#  'sub-NDARINV25PJA9DK',
#  'sub-NDARINV25TV4HPX',
#  'sub-NDARINV25UXU689',
#  'sub-NDARINV263A3T6P',
#  'sub-NDARINV263W8YMY',
#  'sub-NDARINV26AW8K7K',
#  'sub-NDARINV26K18JMC',
#  'sub-NDARINV26L6B73E',
#  'sub-NDARINV26MRFWHN',
#  'sub-NDARINV26V2CZ6Z',
#  'sub-NDARINV26WFVNRJ',
#  'sub-NDARINV26YB6ZJ9',
#  'sub-NDARINV273EJWMX',
#  'sub-NDARINV279N3WC9',
#  'sub-NDARINV27BUCF9E',
#  'sub-NDARINV27BYY712',
#  'sub-NDARINV27CF9R4C',
#  'sub-NDARINV27EPWLDM',
#  'sub-NDARINV27NJ4UJ7',
#  'sub-NDARINV27NU4CMC',
#  'sub-NDARINV27P8BVEW',
#  'sub-NDARINV27VVK0E6',
#  'sub-NDARINV28B5B7EF',
#  'sub-NDARINV28D3LRLF',
#  'sub-NDARINV28DR91DW',
#  'sub-NDARINV28NRLWRX',
#  'sub-NDARINV28X60X09',
#  'sub-NDARINV28X6J47M',
#  'sub-NDARINV28YL6NAY',
#  'sub-NDARINV29299DLJ',
#  'sub-NDARINV29MZKR3H',
#  'sub-NDARINV29P0F670',
#  'sub-NDARINV29RMU5LN',
#  'sub-NDARINV29TAPT8B',
#  'sub-NDARINV29XU24ER',
#  'sub-NDARINV29Y8ZRVC',
#  'sub-NDARINV29YF00DM',
#  'sub-NDARINV2A4GALV7',
#  'sub-NDARINV2A5C0KWW',
#  'sub-NDARINV2ACJBYFC',
#  'sub-NDARINV2AD1P5NV',
#  'sub-NDARINV2AKVW3V7',
#  'sub-NDARINV2AL204UB',
#  'sub-NDARINV2AT88DBZ',
#  'sub-NDARINV2AVRCTAA',
#  'sub-NDARINV2B2ZBYTJ',
#  'sub-NDARINV2B7P1TMR',
#  'sub-NDARINV2B9KMD5C',
#  'sub-NDARINV2BBMM5MF',
#  'sub-NDARINV2BJ826W8',
#  'sub-NDARINV2BKVEFL8',
#  'sub-NDARINV2BPVXTH3',
#  'sub-NDARINV2BUTEB8U',
#  'sub-NDARINV2BW6G83G',
#  'sub-NDARINV2BYAAYTG',
#  'sub-NDARINV2C2HN3CL',
#  'sub-NDARINV2C7F1286',
#  'sub-NDARINV2CB23NEG',
#  'sub-NDARINV2CEAK559',
#  'sub-NDARINV2CK4MB02',
#  'sub-NDARINV2CVVEP68',
#  'sub-NDARINV2CVWTNF7',
#  'sub-NDARINV2CW9FCHV',
#  'sub-NDARINV2D07F24X',
#  'sub-NDARINV2D6AVBFY',
#  'sub-NDARINV2DBPLRUD',
#  'sub-NDARINV2DLW1KXL',
#  'sub-NDARINV2DTHE81G',
#  'sub-NDARINV2DYU5KZK',
#  'sub-NDARINV2DZUL8LC',
#  'sub-NDARINV2E5NFGXW',
#  'sub-NDARINV2E77XGT6',
#  'sub-NDARINV2E8R4820',
#  'sub-NDARINV2EENVRH9',
#  'sub-NDARINV2EJZCHYV',
#  'sub-NDARINV2ELMBVNA',
#  'sub-NDARINV2EN91V04',
#  'sub-NDARINV2ETV199X',
#  'sub-NDARINV2F729N9A',
#  'sub-NDARINV2FMXCB35',
#  'sub-NDARINV2FRF2URF',
#  'sub-NDARINV2FTTVR8J',
#  'sub-NDARINV2FV7FT02',
#  'sub-NDARINV2FV9YY14',
#  'sub-NDARINV2FXB1E4J',
#  'sub-NDARINV2G3T7XUL',
#  'sub-NDARINV2GN2TPG7',
#  'sub-NDARINV2GPZ2973',
#  'sub-NDARINV2GR8F963',
#  'sub-NDARINV2GRXYP02',
#  'sub-NDARINV2H0FM634',
#  'sub-NDARINV2H0H09CW',
#  'sub-NDARINV2H704HJD',
#  'sub-NDARINV2HCFH1VL',
#  'sub-NDARINV2HLV10CC',
#  'sub-NDARINV2J19HL2V',
#  'sub-NDARINV2J3D85NJ',
#  'sub-NDARINV2J50AKJP',
#  'sub-NDARINV2J8WHJ3R',
#  'sub-NDARINV2JC795CJ',
#  'sub-NDARINV2JRRX50R',
#  'sub-NDARINV2K0TR221',
#  'sub-NDARINV2K16Y0LC',
#  'sub-NDARINV2K6WB3XJ',
#  'sub-NDARINV2KBLDWXW',
#  'sub-NDARINV2KJNX54B',
#  'sub-NDARINV2KZR1A9A',
#  'sub-NDARINV2L40420R',
#  'sub-NDARINV2L4FEKF7',
#  'sub-NDARINV2LA00BUD',
#  'sub-NDARINV2LD0E2FB',
#  'sub-NDARINV2LFJV5KT',
#  'sub-NDARINV2LHR28JU',
#  'sub-NDARINV2LL2Y78J',
#  'sub-NDARINV2LUG79YV',
#  'sub-NDARINV2MEH8NFX',
#  'sub-NDARINV2MH3HPHP',
#  'sub-NDARINV2MMJJTBJ',
#  'sub-NDARINV2MMMWY0R',
#  'sub-NDARINV2N0CBXE8',
#  'sub-NDARINV2NDR0B6U',
#  'sub-NDARINV2NGBYVBP',
#  'sub-NDARINV2NLERKN7',
#  'sub-NDARINV2NMMXZ45',
#  'sub-NDARINV2NV4C2CL',
#  'sub-NDARINV2NVAXBZL',
#  'sub-NDARINV2NYH1JCE',
#  'sub-NDARINV2NZV8ELL',
#  'sub-NDARINV2P0HPD40',
#  'sub-NDARINV2P2LLTJC',
#  'sub-NDARINV2P3B9TGH',
#  'sub-NDARINV2P48F0JJ',
#  'sub-NDARINV2P5N7AMV',
#  'sub-NDARINV2P5R504F',
#  'sub-NDARINV2PFVV0YJ',
#  'sub-NDARINV2PG9W3G7',
#  'sub-NDARINV2PHYK8FE',
#  'sub-NDARINV2R0HFJ5Y',
#  'sub-NDARINV2R403NWA',
#  'sub-NDARINV2RCE88HL',
#  'sub-NDARINV2RD4CZ7T',
#  'sub-NDARINV2RJ8ZRGL',
#  'sub-NDARINV2RLDDFYE',
#  'sub-NDARINV2RVWB0HM',
#  'sub-NDARINV2T1G705T',
#  'sub-NDARINV2T6WFDFJ',
#  'sub-NDARINV2T7FRKV1',
#  'sub-NDARINV2TBMGWU5',
#  'sub-NDARINV2TGLF2NG',
#  'sub-NDARINV2TMKUVW7',
#  'sub-NDARINV2TRERCDA',
#  'sub-NDARINV2TTD2LB2',
#  'sub-NDARINV2U3DNEET',
#  'sub-NDARINV2U3P6G9H',
#  'sub-NDARINV2U59DP6L',
#  'sub-NDARINV2U88LX3T',
#  'sub-NDARINV2UHTAC1R',
#  'sub-NDARINV2UR3G0TV',
#  'sub-NDARINV2UWL3APY',
#  'sub-NDARINV2V1TRPDR',
#  'sub-NDARINV2V43CKWH',
#  'sub-NDARINV2V8997BF',
#  'sub-NDARINV2V90MWXP',
#  'sub-NDARINV2VD87TK5',
#  'sub-NDARINV2VGE4HK8',
#  'sub-NDARINV2VGT219A',
#  'sub-NDARINV2VHU0WU5',
#  'sub-NDARINV2VJF8M3C',
#  'sub-NDARINV2VPV9219',
#  'sub-NDARINV2VY7YYNW',
#  'sub-NDARINV2W07991D',
#  'sub-NDARINV2W4EY7DK',
#  'sub-NDARINV2W4HNGV7',
#  'sub-NDARINV2W7FBDN4',
#  'sub-NDARINV2WTW50R0',
#  'sub-NDARINV2WYPW02N',
#  'sub-NDARINV2X02MDU2',
#  'sub-NDARINV2X0UMZF5',
#  'sub-NDARINV2X9JB86Z',
#  'sub-NDARINV2XAHZZ2A',
#  'sub-NDARINV2XDH23JX',
#  'sub-NDARINV2XGC3LN5',
#  'sub-NDARINV2XWVWFF3',
#  'sub-NDARINV2YBXVCKR',
#  'sub-NDARINV2YG2VRCX',
#  'sub-NDARINV2YH5GYE4',
#  'sub-NDARINV2YJD21VH',
#  'sub-NDARINV2YV96ETT',
#  'sub-NDARINV2Z032PK4',
#  'sub-NDARINV2Z2HJFG1',
#  'sub-NDARINV2ZA2LC3N',
#  'sub-NDARINV2ZAMNE5F',
#  'sub-NDARINV2ZC2JPP4',
#  'sub-NDARINV2ZCZ5TAL',
#  'sub-NDARINV2ZFBNJT6',
#  'sub-NDARINV2ZG81XAB',
#  'sub-NDARINV2ZJXDTEL',
#  'sub-NDARINV2ZTVWYR2',
#  'sub-NDARINV302FDTJF',
#  'sub-NDARINV303R5G9A',
#  'sub-NDARINV3072CP0C',
#  'sub-NDARINV3093VDLX',
#  'sub-NDARINV30BGMG0D',
#  'sub-NDARINV31CVPC8B',
#  'sub-NDARINV31NMMY4J',
#  'sub-NDARINV31UPFNDE',
#  'sub-NDARINV3220ZV0N',
#  'sub-NDARINV32KLKRZC',
#  'sub-NDARINV32M7D88U',
#  'sub-NDARINV32P8UGE7',
#  'sub-NDARINV32WKK9XE',
#  'sub-NDARINV32ZTA2YU',
#  'sub-NDARINV330E63GH',
#  'sub-NDARINV330HNJEV',
#  'sub-NDARINV3385AZ13',
#  'sub-NDARINV33AC40WZ',
#  'sub-NDARINV33V4RC97',
#  'sub-NDARINV348PDVUL',
#  'sub-NDARINV34BZY5KP',
#  'sub-NDARINV34H78073',
#  'sub-NDARINV34HCN2RW',
#  'sub-NDARINV34MJX0NC',
#  'sub-NDARINV34RL3DRG',
#  'sub-NDARINV34YGA6HN',
#  'sub-NDARINV352XG4XH',
#  'sub-NDARINV355PUM5E',
#  'sub-NDARINV35DUHZ83',
#  'sub-NDARINV35E50RLA',
#  'sub-NDARINV35KNHNNM',
#  'sub-NDARINV35UXPP43',
#  'sub-NDARINV35ZTAGD8',
#  'sub-NDARINV3617ZB48',
#  'sub-NDARINV361NRHEX',
#  'sub-NDARINV367WJ8ZA',
#  'sub-NDARINV36DKMERA',
#  'sub-NDARINV36E4JVZ2',
#  'sub-NDARINV36K7YFLB',
#  'sub-NDARINV36KEAPWR',
#  'sub-NDARINV36KR4T19',
#  'sub-NDARINV36UHVKLZ',
#  'sub-NDARINV36ZD3NZC',
#  'sub-NDARINV37AGV6H4',
#  'sub-NDARINV37E785RU',
#  'sub-NDARINV37FHEA6B',
#  'sub-NDARINV37FTP2A7',
#  'sub-NDARINV37MKKJBX',
#  'sub-NDARINV37ZMYZNR',
#  'sub-NDARINV385XPJ9D',
#  'sub-NDARINV38FX2APW',
#  'sub-NDARINV38MDKPJC',
#  'sub-NDARINV38MJNWUT',
#  'sub-NDARINV38RT7JJA',
#  'sub-NDARINV38TUEK9N',
#  'sub-NDARINV38UUC1PC',
#  'sub-NDARINV39DK1BKF',
#  'sub-NDARINV39DNG05T',
#  'sub-NDARINV39L4VX1P',
#  'sub-NDARINV39R1KUT6',
#  'sub-NDARINV39Z1U19N',
#  'sub-NDARINV39Z29MG3',
#  'sub-NDARINV3A2DLZTM',
#  'sub-NDARINV3A81U14B',
#  'sub-NDARINV3ACT8TYV',
#  'sub-NDARINV3AD71HE2',
#  'sub-NDARINV3ATWJ2YH',
#  'sub-NDARINV3AY9C1RJ',
#  'sub-NDARINV3B1CZ5GM',
#  'sub-NDARINV3B1PKLZM',
#  'sub-NDARINV3B60KLEU',
#  'sub-NDARINV3B70AX8C',
#  'sub-NDARINV3B78K6LY',
#  'sub-NDARINV3BF8GG8A',
#  'sub-NDARINV3BFH48PE',
#  'sub-NDARINV3BJ59UTE',
#  'sub-NDARINV3BJF2R7E',
#  'sub-NDARINV3BLPP0EZ',
#  'sub-NDARINV3BMMWW3X',
#  'sub-NDARINV3BXUUPAE',
#  'sub-NDARINV3C0FHDGM',
#  'sub-NDARINV3CE271ET',
#  'sub-NDARINV3CF4D0FF',
#  'sub-NDARINV3CR6NXBG',
#  'sub-NDARINV3CUDM6MC',
#  'sub-NDARINV3CVRZ501',
#  'sub-NDARINV3CW8YR0W',
#  'sub-NDARINV3D7TEJUE',
#  'sub-NDARINV3DAXLFDY',
#  'sub-NDARINV3DDJKN73',
#  'sub-NDARINV3DL75W3B',
#  'sub-NDARINV3DMNEA3Z',
#  'sub-NDARINV3DN8DMP3',
#  'sub-NDARINV3DRFHXRC',
#  'sub-NDARINV3E6J6JJR',
#  'sub-NDARINV3EX0WR8L',
#  'sub-NDARINV3F2L795H',
#  'sub-NDARINV3F6NJ6WW',
#  'sub-NDARINV3FJ6DHVU',
#  'sub-NDARINV3FP11AFU',
#  'sub-NDARINV3FZNFM1H',
#  'sub-NDARINV3G46KLE7',
#  'sub-NDARINV3G92P847',
#  'sub-NDARINV3GFD7GXB',
#  'sub-NDARINV3GZNM6F8',
#  'sub-NDARINV3H19ZCF8',
#  'sub-NDARINV3H54D8DK',
#  'sub-NDARINV3H5U1V47',
#  'sub-NDARINV3H81JJ1U',
#  'sub-NDARINV3HBNNTXH',
#  'sub-NDARINV3HC4V43B',
#  'sub-NDARINV3HFPA2R0',
#  'sub-NDARINV3HJUHZX1',
#  'sub-NDARINV3HMZ7DZZ',
#  'sub-NDARINV3HU0G71U',
#  'sub-NDARINV3HV5ZJLJ',
#  'sub-NDARINV3HX1TNWP',
#  'sub-NDARINV3HZG2Y7P',
#  'sub-NDARINV3J93N0EH',
#  'sub-NDARINV3JYXAP1H',
#  'sub-NDARINV3JZ6Y396',
#  'sub-NDARINV3K5PPAFD',
#  'sub-NDARINV3KBYKMJ2',
#  'sub-NDARINV3KCBT1UJ',
#  'sub-NDARINV3KTW4M91',
#  'sub-NDARINV3KZATZ7M',
#  'sub-NDARINV3L9YHDDK',
#  'sub-NDARINV3LA2YW3R',
#  'sub-NDARINV3LTP4JU7',
#  'sub-NDARINV3M6TK7TT',
#  'sub-NDARINV3MANP3Y8',
#  'sub-NDARINV3MJ73KP6',
#  'sub-NDARINV3MLPX0CG',
#  'sub-NDARINV3MNM0TC6',
#  'sub-NDARINV3MNR8TC0',
#  'sub-NDARINV3MR1M0V3',
#  'sub-NDARINV3MTP07E9',
#  'sub-NDARINV3N0KGZ5G',
#  'sub-NDARINV3N6L8Z9U',
#  'sub-NDARINV3NA8KUJ2',
#  'sub-NDARINV3NABWF15',
#  'sub-NDARINV3NBMWRE0',
#  'sub-NDARINV3NGLDPCG',
#  'sub-NDARINV3NMH509V',
#  'sub-NDARINV3NT6ML17',
#  'sub-NDARINV3NVPPNEE',
#  'sub-NDARINV3P0G038K',
#  'sub-NDARINV3P1U2ABW',
#  'sub-NDARINV3P7MECT8',
#  'sub-NDARINV3PB2GNLM',
#  'sub-NDARINV3PJ552TW',
#  'sub-NDARINV3PKXFBNU',
#  'sub-NDARINV3PTPRFM5',
#  'sub-NDARINV3PZ5UBCM',
#  'sub-NDARINV3R1XMUN2',
#  'sub-NDARINV3R9J4MH0',
#  'sub-NDARINV3RXJAR68',
#  'sub-NDARINV3RZ11T2M',
#  'sub-NDARINV3T4N9EJD',
#  'sub-NDARINV3TG667EC',
#  'sub-NDARINV3TGTC3C9',
#  'sub-NDARINV3TKL2EYB',
#  'sub-NDARINV3TMCHLA7',
#  'sub-NDARINV3TRN51XL',
#  'sub-NDARINV3TT997HJ',
#  'sub-NDARINV3TYW27P3',
#  'sub-NDARINV3U3CWTNF',
#  'sub-NDARINV3UCAB3ZC',
#  'sub-NDARINV3UNMBY32',
#  'sub-NDARINV3UPL5YML',
#  'sub-NDARINV3UW7BCN8',
#  'sub-NDARINV3V05U0Z7',
#  'sub-NDARINV3V7GL5Z2',
#  'sub-NDARINV3VAXZUWK',
#  'sub-NDARINV3VGP47P6',
#  'sub-NDARINV3VU4N68P',
#  'sub-NDARINV3W15L2YE',
#  'sub-NDARINV3W3CHB2Y',
#  'sub-NDARINV3WA4PYL5',
#  'sub-NDARINV3WDYMBWU',
#  'sub-NDARINV3WEDXU2N',
#  'sub-NDARINV3WH5A5LB',
#  'sub-NDARINV3WHJ0U6T',
#  'sub-NDARINV3WMHUK7W',
#  'sub-NDARINV3WRKC6EJ',
#  'sub-NDARINV3WT1TK9L',
#  'sub-NDARINV3WXXPJKW',
#  'sub-NDARINV3X1TYL13',
#  'sub-NDARINV3X48ZM73',
#  'sub-NDARINV3XCZ5XRY',
#  'sub-NDARINV3XKBVA63',
#  'sub-NDARINV3XL11J4W',
#  'sub-NDARINV3XM1RJF0',
#  'sub-NDARINV3XMEM8L9',
#  'sub-NDARINV3XNNBDPH',
#  'sub-NDARINV3XRWEG62',
#  'sub-NDARINV3XVWEYUY',
#  'sub-NDARINV3XW4NJJV',
#  'sub-NDARINV3XZ29M5N',
#  'sub-NDARINV3XZKYEVA',
#  'sub-NDARINV3Y5UF4TX',
#  'sub-NDARINV3YBDL5L3',
#  'sub-NDARINV3YCZGP8H',
#  'sub-NDARINV3YDKCAH1',
#  'sub-NDARINV3YJ5XDU0',
#  'sub-NDARINV3YKLWXF1',
#  'sub-NDARINV3YRA5895',
#  'sub-NDARINV3YXD8CTZ',
#  'sub-NDARINV3YXV3Y6W',
#  'sub-NDARINV3Z0RW5RE',
#  'sub-NDARINV3Z6H844T',
#  'sub-NDARINV3ZC3XKET',
#  'sub-NDARINV3ZHEYRWE',
#  'sub-NDARINV3ZHPLD0X',
#  'sub-NDARINV3ZPDZ9KU',
#  'sub-NDARINV3ZRYG6UB',
#  'sub-NDARINV3ZUH1ZHD',
#  'sub-NDARINV3ZXWNWZK',
#  'sub-NDARINV402278X9',
#  'sub-NDARINV405DYFXP',
#  'sub-NDARINV40BBMD8U',
#  'sub-NDARINV40J0R30V',
#  'sub-NDARINV40JXNNYU',
#  'sub-NDARINV40T7TX7X',
#  'sub-NDARINV415JRYRK',
#  'sub-NDARINV41964BN4',
#  'sub-NDARINV41KABJ1Z',
#  'sub-NDARINV41TZ179J',
#  'sub-NDARINV41U1CNA9',
#  'sub-NDARINV41ZBCH48',
#  'sub-NDARINV4208ZTJH',
#  'sub-NDARINV425E5RC6',
#  'sub-NDARINV427BL6HA',
#  'sub-NDARINV42EDG566',
#  'sub-NDARINV42ELB372',
#  'sub-NDARINV42J1GB3Y',
#  'sub-NDARINV42N70P8A',
#  'sub-NDARINV43AFH5U4',
#  'sub-NDARINV43DEA5HT',
#  'sub-NDARINV43P39GXX',
#  'sub-NDARINV43TD8G0E',
#  'sub-NDARINV43VJ1LGA',
#  'sub-NDARINV43VJ4GZ1',
#  'sub-NDARINV4422DGC4',
#  'sub-NDARINV449WT7FF',
#  'sub-NDARINV44A0LV53',
#  'sub-NDARINV44AD8TE0',
#  'sub-NDARINV44AXV5FM',
#  'sub-NDARINV44FW419F',
#  'sub-NDARINV44K29WLN',
#  'sub-NDARINV44VXW7YA',
#  'sub-NDARINV44WLHHC1',
#  'sub-NDARINV44YMAA5N',
#  'sub-NDARINV459DR5EV',
#  'sub-NDARINV45BG08PF',
#  'sub-NDARINV45F6VJ4T',
#  'sub-NDARINV45HV5L52',
#  'sub-NDARINV45ZYAREH',
#  'sub-NDARINV462XNPPR',
#  'sub-NDARINV46B8VBDT',
#  'sub-NDARINV46BR319Y',
#  'sub-NDARINV46VFKP3F',
#  'sub-NDARINV46X37HLX',
#  'sub-NDARINV474A4X05',
#  'sub-NDARINV476NCATP',
#  'sub-NDARINV47H9F62N',
#  'sub-NDARINV47N6G712',
#  'sub-NDARINV47RJB7Z0',
#  'sub-NDARINV47W6DHJC',
#  'sub-NDARINV486GVBCD',
#  'sub-NDARINV486UUF4D',
#  'sub-NDARINV4878W3DV',
#  'sub-NDARINV48EYUFJ4',
#  'sub-NDARINV48FCH9BT',
#  'sub-NDARINV48LY4MLX',
#  'sub-NDARINV48RC3H1N',
#  'sub-NDARINV493AHEA8',
#  'sub-NDARINV49D4EDYG',
#  'sub-NDARINV4A443KDZ',
#  'sub-NDARINV4AP9GM2Z',
#  'sub-NDARINV4AY58X03',
#  'sub-NDARINV4AYYAKWZ',
#  'sub-NDARINV4B0U03EB',
#  'sub-NDARINV4BA28Y80',
#  'sub-NDARINV4BAX2G31',
#  'sub-NDARINV4BB6Z0VU',
#  'sub-NDARINV4BFTB73U',
#  'sub-NDARINV4BH3W9Z3',
#  'sub-NDARINV4BJ1W8Z2',
#  'sub-NDARINV4BK6Y7VR',
#  'sub-NDARINV4BKN34GB',
#  'sub-NDARINV4BPHYB7J',
#  'sub-NDARINV4BRVTNUE',
#  'sub-NDARINV4BU3CBM5',
#  'sub-NDARINV4BXZZV14',
#  'sub-NDARINV4C12ZREL',
#  'sub-NDARINV4C2YD3TH',
#  'sub-NDARINV4C616XF8',
#  'sub-NDARINV4C8YJ9BG',
#  'sub-NDARINV4CB96L7N',
#  ...]

# %%
#Creating the classification model
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

classifier = Sequential()
#First Hidden Layer
classifier.add(Dense(32, activation='tanh', kernel_initializer='random_normal', input_shape=x_train.shape[1:]))
#Second  Hidden Layer
classifier.add(Dense(16, activation='relu', kernel_initializer='random_normal'))
#Third  Hidden Layer
classifier.add(Dense(16, activation='relu', kernel_initializer='random_normal'))
#Output Layer
classifier.add(Dense(1, activation='sigmoid', kernel_initializer='random_normal'))

# %%
classifier.compile(optimizer = Adam(lr =.0001),loss='binary_crossentropy', metrics =['accuracy'])

# %%
classifier.fit(x_train_tf,y_train_recode, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 170/170 [==============================] - 3s 5ms/step - loss: 0.6927 - accuracy: 0.5163
# Epoch 2/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.6849 - accuracy: 0.7256
# Epoch 3/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.6288 - accuracy: 0.8624
# Epoch 4/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.4766 - accuracy: 0.9097
# Epoch 5/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.3019 - accuracy: 0.9442
# Epoch 6/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.2062 - accuracy: 0.9466
# Epoch 7/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.1237 - accuracy: 0.9773
# Epoch 8/100
# 170/170 [==============================] - 1s 7ms/step - loss: 0.0784 - accuracy: 0.9860
# Epoch 9/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0577 - accuracy: 0.9902
# Epoch 10/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0481 - accuracy: 0.9891
# Epoch 11/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0397 - accuracy: 0.9908
# Epoch 12/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0305 - accuracy: 0.9941
# Epoch 13/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0296 - accuracy: 0.9940
# Epoch 14/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0269 - accuracy: 0.9945
# Epoch 15/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0218 - accuracy: 0.9956
# Epoch 16/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0160 - accuracy: 0.9963
# Epoch 17/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0250 - accuracy: 0.9940
# Epoch 18/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0116 - accuracy: 0.9978
# Epoch 19/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0143 - accuracy: 0.9968
# Epoch 20/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0177 - accuracy: 0.9969
# Epoch 21/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0156 - accuracy: 0.9969
# Epoch 22/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0136 - accuracy: 0.9968
# Epoch 23/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0123 - accuracy: 0.9978
# Epoch 24/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0115 - accuracy: 0.9976
# Epoch 25/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0211 - accuracy: 0.9959
# Epoch 26/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0458 - accuracy: 0.9888
# Epoch 27/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0216 - accuracy: 0.9942
# Epoch 28/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0157 - accuracy: 0.9966
# Epoch 29/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0060 - accuracy: 0.9985
# Epoch 30/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0134 - accuracy: 0.9964
# Epoch 31/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0077 - accuracy: 0.9979
# Epoch 32/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0094 - accuracy: 0.9977
# Epoch 33/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0081 - accuracy: 0.9983
# Epoch 34/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0075 - accuracy: 0.9981
# Epoch 35/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0086 - accuracy: 0.9971
# Epoch 36/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0095 - accuracy: 0.9979
# Epoch 37/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0064 - accuracy: 0.9983
# Epoch 38/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0072 - accuracy: 0.9977
# Epoch 39/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0071 - accuracy: 0.9982
# Epoch 40/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0051 - accuracy: 0.9992
# Epoch 41/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0094 - accuracy: 0.9976
# Epoch 42/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0046 - accuracy: 0.9989
# Epoch 43/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0091 - accuracy: 0.9976
# Epoch 44/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0076 - accuracy: 0.9978
# Epoch 45/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0099 - accuracy: 0.9967
# Epoch 46/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0081 - accuracy: 0.9977
# Epoch 47/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0069 - accuracy: 0.9982
# Epoch 48/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0067 - accuracy: 0.9979
# Epoch 49/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0073 - accuracy: 0.9986
# Epoch 50/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0062 - accuracy: 0.9980
# Epoch 51/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 52/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.9992
# Epoch 53/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0026 - accuracy: 0.9994
# Epoch 54/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0078 - accuracy: 0.9977
# Epoch 55/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0056 - accuracy: 0.9978
# Epoch 56/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0048 - accuracy: 0.9981
# Epoch 57/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0046 - accuracy: 0.9989
# Epoch 58/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0062 - accuracy: 0.9983
# Epoch 59/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0547 - accuracy: 0.9783
# Epoch 60/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0358 - accuracy: 0.9883
# Epoch 61/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0180 - accuracy: 0.9960
# Epoch 62/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0068 - accuracy: 0.9991
# Epoch 63/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0056 - accuracy: 0.9991
# Epoch 64/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0043 - accuracy: 0.9994
# Epoch 65/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.9996
# Epoch 66/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0064 - accuracy: 0.9986
# Epoch 67/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0048 - accuracy: 0.9989
# Epoch 68/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0041 - accuracy: 0.9986
# Epoch 69/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0074 - accuracy: 0.9987
# Epoch 70/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0041 - accuracy: 0.9992
# Epoch 71/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.9996
# Epoch 72/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0028 - accuracy: 0.9998
# Epoch 73/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.9996
# Epoch 74/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.9997
# Epoch 75/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0058 - accuracy: 0.9990
# Epoch 76/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0073 - accuracy: 0.9990
# Epoch 77/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0047 - accuracy: 0.9993
# Epoch 78/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0033 - accuracy: 0.9996
# Epoch 79/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0030 - accuracy: 0.9997
# Epoch 80/100
# 170/170 [==============================] - 1s 6ms/step - loss: 0.0052 - accuracy: 0.9985
# Epoch 81/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0023 - accuracy: 0.9999
# Epoch 82/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0020 - accuracy: 0.9999
# Epoch 83/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0023 - accuracy: 0.9998
# Epoch 84/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0023 - accuracy: 0.9994
# Epoch 85/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 86/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0026 - accuracy: 0.9998
# Epoch 87/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0028 - accuracy: 0.9997
# Epoch 88/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0023 - accuracy: 0.9998
# Epoch 89/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0042 - accuracy: 0.9994
# Epoch 90/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.9995
# Epoch 91/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0021 - accuracy: 0.9995
# Epoch 92/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0028 - accuracy: 0.9996
# Epoch 93/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0015 - accuracy: 0.9999
# Epoch 94/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0814 - accuracy: 0.9715
# Epoch 95/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0206 - accuracy: 0.9937
# Epoch 96/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0077 - accuracy: 0.9989
# Epoch 97/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0052 - accuracy: 0.9991
# Epoch 98/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0060 - accuracy: 0.9987
# Epoch 99/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0043 - accuracy: 0.9991
# Epoch 100/100
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0044 - accuracy: 0.9992
